# %% [markdown]
# # EDA Notebook - Telemetry Heart AI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Download dataset
import sys
sys.path.append('..')
from scripts.download_heart import download_heart_dataset

df = download_heart_dataset()
print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import sys
#       8 sys.path.append('..')
# ----> 9 from scripts.download_heart import download_heart_dataset
#      11 df = download_heart_dataset()
#      12 print(f"Dataset shape: {df.shape}")
#
# ModuleNotFoundError: No module named 'scripts.download_heart'

# %%
# Basic info
print(df.head())
print(df.describe())
print(df.info())

# %%
# Distribution of target
sns.countplot(data=df, x='target')
plt.title('Distribuci\u00f3n de Target')
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlaci\u00f3n')
plt.show()

# %%
# Feature distributions
fig, axes = plt.subplots(3, 5, figsize=(15, 10))
axes = axes.ravel()
for idx, col in enumerate(df.columns):
    if idx < len(axes):
        axes[idx].hist(df[col], bins=20, edgecolor='black')
        axes[idx].set_title(col)
plt.tight_layout()
plt.show()

print("EDA Complete!")
